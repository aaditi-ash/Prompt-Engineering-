# %% [markdown]
# # SETUP

# %%
import pandas as pd
import google.generativeai as genai

genai.configure(api_key="ENTER API KEY")

# %%
def get_dataset_string(file_path):
    try:
        df = pd.read_csv(file_path)
        return df.to_string(index=False)
    except FileNotFoundError:
        return "CSV file not found. "

data = 'dataset.csv'
data = get_dataset_string(data)
print(data)
# Out:
#                                   Prompt Prompt_Type  Prompt_Length                                                                                                                                                             Response
#    Where do you see yourself in 5 years?    Question             37                                                                            In 5 years, I see myself advancing in my career and possibly settling down with a family.
#  Summarize the plot of Romeo and Juliet.     Command             39 Romeo and Juliet is a tragedy by William Shakespeare that tells the story of two young star-crossed lovers whose deaths ultimately reconcile their feuding families.
#                   I'm feeling sad today.  Open-ended             22                                        I'm sorry to hear that you're feeling down. It's okay to have off days, and it's important to take time to care for yourself.
# Why do you think education is important?    Question             40                                                               I believe education is important because it empowers individuals and contributes to societal progress.
#   List the ingredients for making pizza.     Command             38                                     To make pizza, you'll need dough, tomato sauce, cheese, and your choice of toppings like pepperoni, mushrooms, and bell peppers.
#             I don't understand calculus.  Open-ended             28                                                                Calculus can be challenging, but with the right resources and dedication, you can certainly grasp it.
# Why do you think education is important?    Question             40                                                               I believe education is important because it empowers individuals and contributes to societal progress.
#  Describe the process of photosynthesis.     Command             39                                        Photosynthesis is the process by which green plants convert carbon dioxide and water into glucose and oxygen, using sunlight.
#             I don't understand calculus.  Open-ended             28                                                                Calculus can be challenging, but with the right resources and dedication, you can certainly grasp it.
#       What are the benefits of exercise?    Question             34                                                                   Exercise helps improve physical health, boosts mental well-being, and enhances cognitive function.
#  Describe the process of photosynthesis.     Command             39                                        Photosynthesis is the process by which green plants convert carbon dioxide and water into glucose and oxygen, using sunlight.
#             I don't understand calculus.  Open-ended             28                                                                Calculus can be challenging, but with the right resources and dedication, you can certainly grasp it.
#       What are the benefits of exercise?    Question             34                                                                   Exercise helps improve physical health, boosts mental well-being, and enhances cognitive function.
#               Explain quantum mechanics.     Command             26                                    Quantum mechanics is a branch of physics that deals with systems on a very small scale, typically atomic and subatomic particles.
#              The weather is really nice.  Open-ended             27                                                                                                     That's great to hear! Good weather can really lift your spirits.
#    Where do you see yourself in 5 years?    Question             37                                                                            In 5 years, I see myself advancing in my career and possibly settling down with a family.
#                          Tell me a joke.     Command             15                                                                                         Why did the scarecrow win an award? Because he was outstanding in his field!
#              The weather is really nice.  Open-ended             27                                                                                                     That's great to hear! Good weather can really lift your spirits.
# Why do you think education is important?    Question             40                                                               I believe education is important because it empowers individuals and contributes to societal progress.
#  Summarize the plot of Romeo and Juliet.     Command             39 Romeo and Juliet is a tragedy by William Shakespeare that tells the story of two young star-crossed lovers whose deaths ultimately reconcile their feuding families.
#             I don't understand calculus.  Open-ended             28                                                                Calculus can be challenging, but with the right resources and dedication, you can certainly grasp it.
# Why do you think education is important?    Question             40                                                               I believe education is important because it empowers individuals and contributes to societal progress.
#  Describe the process of photosynthesis.     Command             39                                        Photosynthesis is the process by which green plants convert carbon dioxide and water into glucose and oxygen, using sunlight.
#                   I'm feeling sad today.  Open-ended             22                                        I'm sorry to hear that you're feeling down. It's okay to have off days, and it's important to take time to care for yourself.
#                   How do you cook pasta?    Question             22                                                                           To cook pasta, you need to boil water, add salt, and then cook the pasta for 8-10 minutes.
#               Explain quantum mechanics.     Command             26                                    Quantum mechanics is a branch of physics that deals with systems on a very small scale, typically atomic and subatomic particles.
#             I don't understand calculus.  Open-ended             28                                                                Calculus can be challenging, but with the right resources and dedication, you can certainly grasp it.
#       What are the benefits of exercise?    Question             34                                                                   Exercise helps improve physical health, boosts mental well-being, and enhances cognitive function.
#   List the ingredients for making pizza.     Command             38                                     To make pizza, you'll need dough, tomato sauce, cheese, and your choice of toppings like pepperoni, mushrooms, and bell peppers.
#                   I'm feeling sad today.  Open-ended             22                                        I'm sorry to hear that you're feeling down. It's okay to have off days, and it's important to take time to care for yourself.
# Why do you think education is important?    Question             40                                                               I believe education is important because it empowers individuals and contributes to societal progress.
#                          Tell me a joke.     Command             15                                                                                         Why did the scarecrow win an award? Because he was outstanding in his field!
#                   The movie was amazing.  Open-ended             22                                                                                               I'm glad you enjoyed the movie! A good film can be a wonderful escape.
# Why do you think education is important?    Question             40                                                               I believe education is important because it empowers individuals and contributes to societal progress.
#                          Tell me a joke.     Command             15                                                                                         Why did the scarecrow win an award? Because he was outstanding in his field!
#                   The movie was amazing.  Open-ended             22                                                                                               I'm glad you enjoyed the movie! A good film can be a wonderful escape.
# Why do you think education is important?    Question             40                                                               I believe education is important because it empowers individuals and contributes to societal progress.
#               Explain quantum mechanics.     Command             26                                    Quantum mechanics is a branch of physics that deals with systems on a very small scale, typically atomic and subatomic particles.

# Why do you think education is important?    Question             40                                                               I believe education is important because it empowers individuals and contributes to societal progress.
#                          Tell me a joke.     Command             15                                                                                         Why did the scarecrow win an award? Because he was outstanding in his field!
#             I don't understand calculus.  Open-ended             28                                                                Calculus can be challenging, but with the right resources and dedication, you can certainly grasp it.
#       What are the benefits of exercise?    Question             34                                                                   Exercise helps improve physical health, boosts mental well-being, and enhances cognitive function.
#  Summarize the plot of Romeo and Juliet.     Command             39 Romeo and Juliet is a tragedy by William Shakespeare that tells the story of two young star-crossed lovers whose deaths ultimately reconcile their feuding families.
#                   The movie was amazing.  Open-ended             22                                                                                               I'm glad you enjoyed the movie! A good film can be a wonderful escape.
#    Where do you see yourself in 5 years?    Question             37                                                                            In 5 years, I see myself advancing in my career and possibly settling down with a family.
#               Explain quantum mechanics.     Command             26                                    Quantum mechanics is a branch of physics that deals with systems on a very small scale, typically atomic and subatomic particles.
#                   The movie was amazing.  Open-ended             22                                                                                               I'm glad you enjoyed the movie! A good film can be a wonderful escape.
#       What are the benefits of exercise?    Question             34                                                                   Exercise helps improve physical health, boosts mental well-being, and enhances cognitive function.
#               Explain quantum mechanics.     Command             26                                    Quantum mechanics is a branch of physics that deals with systems on a very small scale, typically atomic and subatomic particles.
#                   The movie was amazing.  Open-ended             22                                                                                               I'm glad you enjoyed the movie! A good film can be a wonderful escape.
#                   How do you cook pasta?    Question             22                                                                           To cook pasta, you need to boil water, add salt, and then cook the pasta for 8-10 minutes.
#                          Tell me a joke.     Command             15                                                                                         Why did the scarecrow win an award? Because he was outstanding in his field!
#              The weather is really nice.  Open-ended             27                                                                                                     That's great to hear! Good weather can really lift your spirits.
#             What is your favorite color?    Question             28                                                                                                                                           My favorite color is blue.
#  Describe the process of photosynthesis.     Command             39                                        Photosynthesis is the process by which green plants convert carbon dioxide and water into glucose and oxygen, using sunlight.
#                   I'm feeling sad today.  Open-ended             22                                        I'm sorry to hear that you're feeling down. It's okay to have off days, and it's important to take time to care for yourself.
#             What is your favorite color?    Question             28                                                                                                                                           My favorite color is blue.
#                          Tell me a joke.     Command             15                                                                                         Why did the scarecrow win an award? Because he was outstanding in his field!
#             I don't understand calculus.  Open-ended             28                                                                Calculus can be challenging, but with the right resources and dedication, you can certainly grasp it.
# Why do you think education is important?    Question             40                                                               I believe education is important because it empowers individuals and contributes to societal progress.
#  Describe the process of photosynthesis.     Command             39                                        Photosynthesis is the process by which green plants convert carbon dioxide and water into glucose and oxygen, using sunlight.
#                   I'm feeling sad today.  Open-ended             22                                        I'm sorry to hear that you're feeling down. It's okay to have off days, and it's important to take time to care for yourself.
#                   How do you cook pasta?    Question             22                                                                           To cook pasta, you need to boil water, add salt, and then cook the pasta for 8-10 minutes.
#   List the ingredients for making pizza.     Command             38                                     To make pizza, you'll need dough, tomato sauce, cheese, and your choice of toppings like pepperoni, mushrooms, and bell peppers.
#             I don't understand calculus.  Open-ended             28                                                                Calculus can be challenging, but with the right resources and dedication, you can certainly grasp it.

# %%
model = genai.GenerativeModel('gemini-2.0-flash-lite')

# %% [markdown]
# # QUESTIONS

# %% [markdown]
# Question 1: Column Exploration Challenge
#
# "You suspect there’s a column that contains various categories or themes within prompt engineering (e.g., types of prompts or model behaviors). Craft a prompt that helps you find out what these categories might be."
#
#  Expected skill output: Schema inference, descriptive prompting

# %%
PROMPT = "Analyze the dataset and identify a column that categorizes the prompts by their function or purpose."


full_prompt = f"Given the following dataset from a CSV file, {PROMPT}\n\nDataset:\n{data}"

response = model.generate_content(full_prompt)
print(response.text)
# Out:
# Based on the dataset provided, the column that categorizes the prompts by their function or purpose is **Prompt_Type**.
#
# Here's why:
#
# *   **Prompt_Type** clearly labels each prompt into categories like "Question," "Command," and "Open-ended." These categories reflect the function or intent behind the prompt.
#
# *   Other columns like "Prompt" (the actual text) and "Response" (the AI's reply) don't categorize by function.
# *   "Prompt_Length" is not the category we are looking for.

# %% [markdown]
# Question 2: Detect the Outlier
#
# "Some rows in the dataset may not align well with the rest in terms of a specific metric like accuracy, BLEU score, or token usage. Without directly referencing those metrics, craft a prompt that will help you detect anomalies in the dataset."
#
# Expected skill: Implicit querying, understanding of outlier detection through prompting

# %%
PROMPT = "Examine the responses in the dataset. Are there any entries where the response seems \
          too long, or completely unrelated to the prompt, compared to the others?\
          If so, list out the rows and state the exact metric you used to catogerise them as an anomaly.\
          Do not list out the rows that have no anomalies."

full_prompt = f"Given the following dataset from a CSV file, {PROMPT}\n\nDataset:\n{data}"

response = model.generate_content(full_prompt)
print(response.text)
# Out:
# Here's the analysis of the dataset, identifying anomalies based on the length of the response:
#
# **Anomalies based on Response Length:**
#
# *   **Row 12**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 121**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 199**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 229**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 261**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 293**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 325**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 357**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 389**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 421**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 453**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 485**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 517**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 549**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 581**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 613**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 645**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 677**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 709**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 741**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 773**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 805**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 837**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 869**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 901**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 933**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 965**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 997**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1029**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1061**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1093**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1125**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1157**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1189**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1221**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1253**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1285**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1317**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1349**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1381**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1413**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1445**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1477**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1509**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1541**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1573**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1605**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1637**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1669**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1701**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1733**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1765**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1797**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1829**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1861**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1893**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1925**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1957**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 1989**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 2021**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 2053**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 2085**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 2117**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 2149**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 2181**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 2213**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 2245**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 2277**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 2309**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 2341**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 2373**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 2405**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal, since they are not bound by a set size of answer.
#     *   This also applies to Question type prompts.
# *   The answer to the question, as the prompt already states "What is your favorite color?", a simple statement like this is the expected result.
#
# *   **Row 2437**
#     *   **Metric:** The response to the prompt "What is your favorite color?" is just "My favorite color is blue."
#
# **Justification**
#
# *   All Open Ended responses have been classified as normal

# %% [markdown]
# Question 3: Temporal Trend Insight
#
# "Assume the dataset includes timestamps or progression data. Design a prompt that could help you understand how the performance or focus of prompt engineering has evolved over time."

# %%
PROMPT = "analyse the timestamps for each entry and how the characteristics of prompts and their\
      corresponding responses have changed over time. \
    For example, have prompt lengths increased, or have certain types of prompts become more common recently?"

full_prompt = f"Given the following dataset from a CSV file, {PROMPT}\n\nDataset:\n{data}"

response = model.generate_content(full_prompt)
print(response.text)
# Out:
# Okay, let's analyze this dataset.  Since there are no timestamps, I'll assume the order in the data provided represents the "time" sequence.
#
# **Overall Trends and Observations**
#
# *   **Variety of Prompt Types:** The dataset includes a mix of Question, Command and Open-ended prompts. This suggests a variety of use cases for the AI.
# *   **Repetitive Content:** A few prompts and responses are repeated frequently (e.g., "Why do you think education is important?", "Tell me a joke"). This might indicate specific areas of focus or a bias in the training data, or perhaps these are intentionally tested.
# *   **Topic Diversity:** The prompts touch upon various topics, from personal feelings ("I'm feeling sad today") to technical subjects ("Explain quantum mechanics"), demonstrating versatility.
# *   **Thematic Clustering:** Notice some related prompts appearing together. (e.g., a series of questions and commands related to food).
#
# **Detailed Analysis by Type**
#
# Here's how the characteristics evolve over the sequence (time):
#
# 1.  **Prompt Length (Overall):**
#     *   The 'Prompt\_Length' column is available, so it is possible to calculate average prompt lengths and see how this changes over time, calculating the average length for every 10-15 entries.
#     *   There is a wide variance in length.
#     *   The average length overall might indicate whether more complex or simpler prompts are being used.
#
# 2.  **Prompt Type Frequency:**
#     *   **Question Prompts:**
#         *   Relatively frequent, indicating the AI is often used to answer questions.
#         *   Note the frequency of "Why do you think education is important?"  - This could suggest specific areas of testing or a focus in the system's training.
#     *   **Command Prompts:**
#         *   Also common, showing the AI is used for tasks and instructions (e.g., "Summarize the plot of Romeo and Juliet").
#         *   Examples like "Tell me a joke" indicate a desire for creative or entertaining output.
#     *   **Open-ended Prompts:**
#         *   These prompts seem to be used for more conversational and empathetic interactions (e.g., "I'm feeling sad today.")
#         *   The frequency here can be assessed to understand the extent to which the AI is being used for personal interaction.
#
# 3.  **Response Characteristics:**
#     *   **Response Lengths:**
#         *   The responses show variability. Longer responses are more common for instructions and question answering than those for expressing feelings.
#     *   **Response Complexity:**
#         *   Are the responses becoming more detailed, more concise, or showing any evolution in the level of detail over time? This is difficult to assess qualitatively.
#
# **How to Use this for Real-World Analysis (if there were timestamps)**
#
# If the dataset included timestamps, we could conduct a much more powerful analysis:
#
# 1.  **Temporal Trends:**
#
#     *   Plot the frequency of each `Prompt_Type` over time (e.g., number of "Question" prompts per day, week, etc.). This would reveal if certain types of interaction are becoming more or less popular.
#     *   Track the average `Prompt_Length` over time. Are prompts getting longer or shorter?  This could indicate user behavior changes or changes in the system's capabilities.
#     *   Analyze the relationship between prompt type and length. Are longer prompts more likely to be questions, commands, or open-ended statements?
#     *   Analyze the topics of the prompts over time. This can be done manually by classifying the topics (e.g., math, relationships, humor) or using NLP techniques (topic modeling) to identify key themes and their changes in frequency.
#
# 2.  **Relationship between Prompts and Responses:**
#
#     *   Calculate the correlation between `Prompt_Length` and `Response_Length`. Do longer prompts generally receive longer responses?
#     *   Analyze the sentiment of both the prompt and the response.  Are responses more positive or empathetic when the prompt expresses a negative sentiment?
#     *   Look for patterns in the content of responses to specific prompts over time.  Do the responses to a particular question evolve?
#
# 3.  **Identifying Anomalies:**
#
#     *   Look for sudden spikes in certain types of prompts (e.g., a surge in requests for help with math problems).  This might indicate a specific event or a shift in the user base.
#     *   Look for unusual patterns in response quality (e.g., a period of consistently short or unhelpful answers).
#
# **In Conclusion**
#
# Without timestamps, the analysis is limited. But, based on the order of the data:
#
# *   The dataset appears to be a good mix of different prompt types and themes.
# *   We could compare the distribution of prompt types, content, and response details at different points in time by dividing the dataset into sections (e.g., halves or quarters) and comparing those.
#
# Let me know if you would like me to attempt more targeted analysis, given the constraints of a lack of timestamps. For example, I could compare the responses to the prompts in the first half of the data to those in the second half.

# %% [markdown]
# Question 4: Who’s the Top Performer?
#
# "Imagine this dataset tracks various LLMs or techniques. Construct a prompt that helps you determine which model or strategy consistently performs the best — without directly asking 'which model is best?'"

# %%
PROMPT = "Assume the rows are input and outputs of various LLMs.\
    Analyse the model responses and identify the prompt type or technique that consistently produces\
      the most detailed, relevant, and well-structured responses. \
        Provide examples of these high-performing prompts."

full_prompt = f"Given the following dataset from a CSV file, {PROMPT}\n\nDataset:\n{data}"

response = model.generate_content(full_prompt)
print(response.text)
# Out:
# Based on the provided dataset, the prompt type that consistently produces the most detailed, relevant, and well-structured responses is **Command**.
#
# **Examples of High-Performing Prompts (Commands):**
#
# *   "Summarize the plot of Romeo and Juliet."
# *   "Describe the process of photosynthesis."
# *   "List the ingredients for making pizza."
# *   "Explain quantum mechanics."
#
# **Reasoning:**
#
# *   **Commands vs. Other Types:** Commands, in this dataset, consistently generated responses that directly answered the prompt by providing information in a structured manner. They delivered factual, concise explanations, lists, or summaries. Other prompt types, such as open-ended, led to less informative responses (e.g., the responses to "I'm feeling sad today" or "The weather is really nice."). Question prompts also frequently resulted in generic responses, such as "Why do you think education is important?".
#
# *   **Structure and Detail:** Commands typically produced more detailed and structured responses because they directly requested specific information or actions. This often forced the LLM to organize its response in a coherent way, providing clarity and focus.
#
# *   **Relevance:** Responses to commands were highly relevant because they directly addressed the prompt's objective. The LLM was directly instructed to provide a specific piece of information, leading to a more targeted and efficient response.
#
# **Note on Open-ended Questions:**
#
# While the dataset doesn't show it, a more complex and detailed command could also work. E.g. "Analyze the impact of the printing press on societal changes." However, open-ended questions can sometimes elicit a greater variety of detailed responses depending on the model and how the question is formulated.
#
# In summary, for this dataset, **Commands** prove to be the most reliable and effective approach for obtaining detailed, relevant, and well-structured responses.

# %% [markdown]
# Question 5: Summarize a Class of Records
#
# "There’s a category of prompts labeled under a common theme — like 'Chain-of-Thought' or 'Few-Shot'. Write a prompt that gives you a detailed overview of just this category."

# %%
PROMPT = "based on the 'prompt'column label the rows under a common category of prompts — like 'Chain-of-Thought' or 'Few-Shot'.\
    provide a detailed summary of all the entries that have the same prompt type. \
    What are the common characteristics of these prompts and their responses? What is the overall purpose of this category?"

full_prompt = f"Given the following dataset from a CSV file, {PROMPT}\n\nDataset:\n{data}"

response = model.generate_content(full_prompt)
print(response.text)
# Out:
# Here's a breakdown of the prompt types, their common characteristics, and their overall purpose based on the provided dataset.
#
# **1. Question**
#
# *   **Summary of Entries:**
#     *   Where do you see yourself in 5 years? (Repeated multiple times)
#     *   Why do you think education is important? (Repeated multiple times)
#     *   What are the benefits of exercise? (Repeated multiple times)
#     *   How do you cook pasta? (Repeated multiple times)
#     *   What is your favorite color? (Repeated multiple times)
#
# *   **Common Characteristics:**
#     *   They are phrased as questions.
#     *   They require the language model to provide information or opinions.
#     *   The answers can vary greatly in length and style depending on the specific question.
#     *   The questions often seek information, opinions, or advice.
#
# *   **Overall Purpose:**
#     *   To elicit information, opinions, or guidance from the language model.
#     *   To gauge the language model's knowledge and ability to formulate responses.
#     *   To start a conversation or gather information from the model.
#
# **2. Command**
#
# *   **Summary of Entries:**
#     *   Summarize the plot of Romeo and Juliet. (Repeated multiple times)
#     *   List the ingredients for making pizza. (Repeated multiple times)
#     *   Describe the process of photosynthesis. (Repeated multiple times)
#     *   Explain quantum mechanics. (Repeated multiple times)
#     *   Tell me a joke. (Repeated multiple times)
#
# *   **Common Characteristics:**
#     *   They are phrased as instructions or requests for action.
#     *   They usually prompt the language model to generate text in a specific format or provide information in a concise manner.
#
# *   **Overall Purpose:**
#     *   To instruct the language model to perform a specific task or generate a specific output.
#     *   To extract information from the language model in a structured or targeted way.
#
# **3. Open-ended**
#
# *   **Summary of Entries:**
#     *   I'm feeling sad today. (Repeated multiple times)
#     *   I don't understand calculus. (Repeated multiple times)
#     *   The weather is really nice. (Repeated multiple times)
#     *   The movie was amazing. (Repeated multiple times)
#     *   I'm planning to travel. (Repeated multiple times)
#
# *   **Common Characteristics:**
#     *   They are statements or expressions of feeling, providing the language model with context.
#     *   They invite the language model to respond with a supportive, or relevant statement.
#
# *   **Overall Purpose:**
#     *   To elicit a personalized or empathetic response from the language model.
#     *   To create a conversational tone and allow for open-ended responses based on the model's internal knowledge and training.
#     *   To see if the model can understand and appropriately respond to a wide range of user inputs.

# %% [markdown]
# Question 6: Column Mapping Without Metadata
#
# "You don’t know what any of the columns are, but you want to understand which column contains numeric performance metrics. Design a prompt to help the LLM find and describe that column."

# %%
PROMPT = "Assume the column names are not known. Now examine the data in the dataset. Which column \
  appears to contain numerical values, and what do you think those numbers represent? Provide a \
    brief description of the column's likely purpose. If no such column exists, Sate the same"

full_prompt = f"Given the following dataset from a CSV file, {PROMPT}\n\nDataset:\n{data}"

response = model.generate_content(full_prompt)
print(response.text)
# Out:
# Okay, I will analyze the data provided.
#
# **Column with Numerical Values and Interpretation:**
#
# The column that appears to contain numerical values is the **"Prompt_Length"** column.
#
# **Likely Purpose:**
#
# The numbers in the "Prompt_Length" column most likely represent the **number of characters or words** in the "Prompt" column's string.
#
# **In summary, the "Prompt_Length" column's purpose is to provide a length measurement for each of the prompts.**

# %% [markdown]
# Question 7: Cross-column Reasoning
#
# "You want to know if there's a correlation between the length of prompts and the scores they receive. Write a prompt that would help you explore this without asking for raw numbers."

# %%
PROMPT = "analyze the relationship between the `Prompt_Length` and the quality of the `Response` given by the LLM. \
  Find the patterns between the length and quality of the reponse.\
  For example: do longer prompts generate better or worse responses than shorter prompts?"

full_prompt = f"Given the following dataset from a CSV file, {PROMPT}\n\nDataset:\n{data}"

response = model.generate_content(full_prompt)
print(response.text)
# Out:
# Okay, I will analyze the dataset to find any patterns between the `Prompt_Length` and the quality of the `Response`.  It's important to note that without a clear, numerical "quality" score for the responses, my analysis will be based on subjective observation and general trends.  I'll try to look for:
#
# *   **Relationship between length and response type/complexity:** Do longer prompts tend to be commands or questions?  Are they more likely to generate complex, nuanced responses or shorter, more factual ones?
# *   **Relationship between length and response "quality" (subjective):**  Do longer prompts seem to elicit more comprehensive, detailed, or insightful responses?  Or do they sometimes lead to less focused or even rambling answers?
# *   **Presence of a "sweet spot":**  Is there a prompt length that seems to generate the "best" responses, or is there no clear correlation?
# *   **Other factors:** Could other variables like prompt type and the specific content of the prompts affect the quality of the responses?
#
# **Observations & Analysis**
#
# I reviewed the dataset provided.  Given the nature of the data, it is difficult to perform a robust, quantitative analysis. I will share my key observations and attempt to draw conclusions based on the limited data:
#
# **1. No clear Correlation:** There doesn't appear to be a strong or consistent correlation between prompt length and the perceived quality or usefulness of the response. The responses are highly variable.  Some shorter prompts elicit useful answers. Others (and longer ones) give less useful answers.
#
# **2. Prompt Type and Length:** It can be observed that questions tend to have longer prompt lengths than commands or open-ended prompts.
#
# **3. Subjective Quality Assessment:**  Due to the repetitive nature of some prompts, the LLM appears to generate the same answers repeatedly. This results in a lack of variety in the quality of the responses.
#
# **Limitations**
#
# *   **Subjectivity:** "Quality" is entirely subjective. Different people might evaluate the responses differently.
# *   **Small Dataset:** The number of examples is limited, and therefore I cannot make strong conclusions.
# *   **Lack of Metrics:** The dataset lacks a clear metric for evaluating response quality (e.g., correctness, completeness, creativity).
# *   **LLM Variations:** The response quality could vary depending on the specific LLM used.
# *   **No Data on Prompt Engineering:**  We don't know anything about how the prompts were *created* (e.g., was any prompt engineering used to try and influence the length or style of responses?).
#
# **Conclusion**
#
# Based on this limited dataset, it's difficult to establish a strong, definitive relationship between prompt length and response quality. The subjective quality of the responses appears to be inconsistent and the variability can be caused by the repetitive nature of some prompts.
#
# *Further Analysis Suggestions:*
#
# *   **Expand the Dataset:** A much larger, more varied dataset would be needed to draw more reliable conclusions.
# *   **Quantify Quality:**  Implement a metric for assessing response quality (e.g., asking humans to rate the responses based on criteria).
# *   **Control for Prompt Type:**  Analyze the results separately for each prompt type (e.g., questions, commands, open-ended).
# *   **Experiment with Prompt Engineering:** Test different ways of phrasing prompts to see how they impact both length and quality.

# %% [markdown]
# Question 8: Suggest an Optimization
#
# "Based on the patterns in the dataset, design a prompt that encourages the model to suggest how prompt engineering techniques could be optimized — particularly those with suboptimal outcomes."

# %%
PROMPT = "identify a category of prompts of length of prompts that often leads to suboptimal outcomes or reponses which are vague. \
        Suggest specific changes or optimizations to that category of prompts that could improve the quality of the responses.\
        Use examples from the dataset as a guide."

full_prompt = f"Given the following dataset from a CSV file, {PROMPT}\n\nDataset:\n{data}"

response = model.generate_content(full_prompt)
print(response.text)
# Out:
# Okay, I'll analyze the dataset you provided and identify a category of prompts that tend to elicit suboptimal responses. Then, I'll suggest specific changes and optimizations, using examples from the dataset.
#
# **Category of Prompts Leading to Vague Responses:**
#
# Based on the dataset, the "Open-ended" prompt type often leads to vague, generic, or overly simplistic responses. These prompts invite the model to share its feelings or opinions, which can be challenging for a language model. The responses frequently lack depth, originality, or specific details.
#
# **Examples from the Dataset:**
#
# *   **Prompt:** "I'm feeling sad today."
#     *   **Response:** "I'm sorry to hear that you're feeling down. It's okay to have off days, and it's important to take time to care for yourself."
# *   **Prompt:** "The weather is really nice."
#     *   **Response:** "That's great to hear! Good weather can really lift your spirits."
# *   **Prompt:** "The movie was amazing."
#     *   **Response:** "I'm glad you enjoyed the movie! A good film can be a wonderful escape."
# *   **Prompt:** "I'm planning to travel."
#     *   **Response:** "That sounds exciting! Traveling is a great way to experience new cultures and break out of your routine."
#
# **Improvements and Optimizations for Open-Ended Prompts:**
#
# The primary issue with these prompts is the lack of structure. To improve the quality of the responses, we need to guide the language model towards more detailed and insightful answers. Here are several strategies:
#
# 1.  **Specificity:** Frame the open-ended prompt to invite specific details, emotions, or reasoning.
# 2.  **Contextualization:** Provide context to the open-ended question, this allows the language model to generate more relevant and well-informed responses.
# 3.  **Constraints:** Add a constraint to the response to help guide it to a good outcome.
# 4.  **Follow-up Questions:** Create a series of questions to gather more information.
#
# **Specific Changes and Examples:**
#
# Here are some example prompts in the format of Original Prompt, Optimization Method, Optimized Prompt, and Response
#
# 1.  **Original Prompt:** "I'm feeling sad today."
#     *   **Optimization Method:** Specificity and Contextualization
#     *   **Optimized Prompt:** "I'm feeling sad today. Can you provide some advice on how to improve my mood?"
#     *   **Response:** "I understand that you are feeling sad today. Try to remember your happy memories. Listen to your favorite music, watch a movie, or call a friend."
# 2.  **Original Prompt:** "The weather is really nice."
#     *   **Optimization Method:** Follow-up Questions
#     *   **Optimized Prompt:** "The weather is really nice. Can you recommend some activities to enjoy the great weather?"
#     *   **Response:** "Yes, the weather is nice today. Depending on your preferences, you could go for a walk or bike ride, visit a park or botanical garden, or simply relax outdoors with a book or picnic."
# 3.  **Original Prompt:** "The movie was amazing."
#     *   **Optimization Method:** Contextualization and Constraint
#     *   **Optimized Prompt:** "The movie was amazing. Provide a detailed summary of why the movie was amazing."
#     *   **Response:** "The movie was amazing. The plot had very interesting twists and turns, it kept me on the edge of my seat. The characters are very likable and well-acted."
# 4.  **Original Prompt:** "I'm planning to travel."
#     *   **Optimization Method:** Specificity and Constraints
#     *   **Optimized Prompt:** "I'm planning to travel, what should I expect, and what preparations should I take?"
#     *   **Response:** "That sounds exciting! Traveling is a great way to experience new cultures and break out of your routine. Expect that you should prepare for your travels like planning flights, hotel, and tours. You should pack appropriate attire and keep an eye on your spending money."
#
# **General Guidelines:**
#
# *   **Avoid overly broad questions:** Phrase open-ended prompts as specific requests for information, suggestions, or opinions.
# *   **Encourage detail:** Use language that encourages detailed and specific responses (e.g., "Tell me more about...", "In your opinion, what are the key reasons...").
# *   **Provide context:** Help the model understand the situation or task by giving background information.
# *   **Iterate and refine:** Review the responses and adjust the prompts as needed to improve the quality and relevance of the answers.
#
# By implementing these optimizations, the language model can provide more helpful and insightful responses to open-ended prompts, making the interaction more valuable and engaging.

# %% [markdown]
# Question 9
#
# "Several models in this dataset show close performance scores. Use chain-of-thought prompting to analyze why one slightly outperforms another, based on metadata like prompt type, length, or task."
#
# What it Tests : CoT prompting,
#                 Comparative reasoning across subtle differences
#
# Candidate Task : Select two near-similar entries and use a CoT prompt to reason about differences in outcome.

# %%
PROMPT = "analyze the performance of different prompts in it.\
      Judge the performance of a prompt by the clarity and relevance of its response.\
    Example 1:\
    Prompt: 'Why do you think education is important?'\
    Prompt_Type: Question\
    Prompt_Length: 40\
    Response: 'I believe education is important because it empowers individuals and contributes to societal progress.'\
\
    Example 2:\
    Prompt: 'Where do you see yourself in 5 years?'\
    Prompt_Type: Question\
    Prompt_Length: 37\
    Response: 'In 5 years, I see myself advancing in my career and possibly settling down with a family.'\
The responses for both these prompts are good. \
        Analyse step-by-step to explain why Example 1 might have a slightly better response than Example 2, \
        considering the `Prompt_Type` and `Prompt_Length`.\
Compare the content, length, and type of both prompts. and Look for differences in the quality, depth, and applicability of the responses.\
Use the metadata (`Prompt_Type`, `Prompt_Length`) to connect the prompt's characteristics to the response's quality.\
    "

full_prompt = f"Given the following dataset from a CSV file, {PROMPT}\n\nDataset:\n{data}"

response = model.generate_content(full_prompt)
print(response.text)
# Out:
# Here's an analysis of the prompts and responses, focusing on clarity, relevance, and the influence of `Prompt_Type` and `Prompt_Length`:
#
# **Overall Observations:**
#
# *   **Question prompts** tend to elicit more thoughtful and informative responses, as they encourage the AI to explain or provide insight.
# *   **Command prompts** generally receive concise, direct answers, suitable for tasks like listing ingredients or summarizing.
# *   **Open-ended prompts** (e.g., "I'm feeling sad today") lead to empathetic, but often less content-rich, responses.
# *   **Prompt Length** doesn't consistently correlate with the quality of the response, but well-structured prompts (regardless of length) typically provide better responses.
# *   There is a strong tendency for responses to be consistent in quality for a specific prompt.
#
# **Detailed Analysis (Example-Based):**
#
# **Example 1: Better Response**
#
# *   **Prompt:** "Why do you think education is important?"
#     *   **Prompt\_Type:** Question
#     *   **Prompt\_Length:** 40
#     *   **Response:** "I believe education is important because it empowers individuals and contributes to societal progress."
#
#     *   **Analysis:**
#         *   The question type prompts a thoughtful, well-reasoned answer.
#         *   The response is clear, direct, and provides a concise explanation.
#         *   The length is moderate, which is sufficient to explain, without being overly wordy.
#         *   The response gives a meaningful answer that provides reasons for its perspective.
#
# **Example 2: Good Response**
#
# *   **Prompt:** "Where do you see yourself in 5 years?"
#     *   **Prompt\_Type:** Question
#     *   **Prompt\_Length:** 37
#     *   **Response:** "In 5 years, I see myself advancing in my career and possibly settling down with a family."
#
#     *   **Analysis:**
#         *   The question type again prompts a personal answer.
#         *   The response is clear and relevant.
#         *   The response is a bit generic and short, but covers the requested topics.
#         *   This answer is also well formed.
#
# **Comparative Analysis:**
#
# *   **Example 1 vs. Example 2:** Both responses are good and have a reasonable prompt length. Example 1 has slightly more information and better expresses an explanation.
# *   The most significant difference:
#     *   Example 1 is more impactful in the explanation, it gives the user more information, and it gives the user specific reasons why it thinks education is important.
#
# **Patterns and Trends:**
#
# *   **Questions:** "Why do you think education is important?" and "What are the benefits of exercise?" both yielded good responses. The quality of these answers is due to the question structure that probes the system to provide information.
# *   **Commands:** Commands like "Summarize the plot of Romeo and Juliet." and "List the ingredients for making pizza." give good responses for those tasks. The quality of the responses here is very strong, giving information relevant to the question asked.
# *   **Open-ended prompts:** prompts like "I'm feeling sad today." gave good responses, but they were also very generalized and not very insightful.
#
# **Summary of Prompt Characteristics and Response Quality:**
#
# | Prompt Type      |  Observation                                                                                                    |
# | :--------------- | :------------------------------------------------------------------------------------------------------------- |
# | Question         | Generally good, providing explanations and insight.                                                               |
# | Command          | Concise, direct, and suitable for task-oriented responses.                                                      |
# | Open-ended       | Empathetic, but may be less content-rich and more generic.                                                       |
# | Prompt Length    | Doesn't strongly dictate quality, but clarity and structure in prompt do.                                     |
#
# **Conclusion:**
#
# The dataset showcases the AI's ability to respond appropriately based on the prompt's structure. Clear and specific prompts, regardless of the prompt type, generally result in the most satisfactory responses. Questions and Commands are often the most impactful and insightful prompts.

# %% [markdown]
# Question 10
#
# "This dataset includes various prompt formats and their outcomes. Assume you are designing a new prompt technique. Given two successful examples, write a few-shot prompt that the model can generalize from to generate more high-performing prompts."
#
# What it Tests : Few-shot formatting and instruction construction, Understanding of task generalization
#
# Candidate Task : Extract 2–3 high-performing prompt examples and construct a few-shot template that could be reused.

# %%
PROMPT = """ Analyse it and create new prompts that are clear and concise.Here are two examples of successful prompts and their corresponding attributes from a dataset.
      These prompts are considered successful because they elicit a direct and factual response.
Example 1:
Prompt: "Summarize the plot of Romeo and Juliet."
Prompt_Type: Command
Prompt_Length: 39
Response: "Romeo and Juliet is a tragedy by William Shakespeare that tells the story of two young star-crossed lovers whose deaths ultimately reconcile their feuding families."

Example 2:
Prompt: "List the ingredients for making pizza."
Prompt_Type: Command
Prompt_Length: 38
Response: "To make pizza, you'll need dough, tomato sauce, cheese, and your choice of toppings like pepperoni, mushrooms, and bell peppers."

Your task is to generate a similar example which is high performing.
Using these examples as a template, your task is to generate a new, high-performing prompt that follows the same "Command" style.
The new prompt should be similar in length and structure, and should be of command type, 
for example asking for a summary, list, or factual statement on a new topic.
Follow this structure:
New Prompt:
Prompt_Type: Command
Prompt_Length: [your generated length]
Prompt: '[your generated prompt]'
Response: '[Generate the response]'

Give 5 new propmts.
"""

full_prompt = f"Given the following dataset from a CSV file, {PROMPT}\n\nDataset:\n{data}"

response = model.generate_content(full_prompt)
print(response.text)
# Out:
# Here are five new, high-performing prompts based on the dataset, following the "Command" style:
#
# New Prompt:
# Prompt_Type: Command
# Prompt_Length: 30
# Prompt: 'List the steps for changing a car tire.'
# Response: "To change a car tire, you'll need to: 1) Gather tools (spare tire, jack, wrench). 2) Loosen lug nuts. 3) Position the jack and raise the car. 4) Remove lug nuts and the flat tire. 5) Mount the spare tire and tighten lug nuts. 6) Lower the car and fully tighten lug nuts."
#
# New Prompt:
# Prompt_Type: Command
# Prompt_Length: 28
# Prompt: 'Summarize the plot of Hamlet.'
# Response: "Hamlet is a tragedy about a Danish prince seeking revenge for his father's murder, which leads to widespread death and destruction in the royal court."
#
# New Prompt:
# Prompt_Type: Command
# Prompt_Length: 28
# Prompt: 'Explain the water cycle.'
# Response: "The water cycle involves: 1) Evaporation (water turns to vapor). 2) Condensation (vapor turns to liquid). 3) Precipitation (water falls). 4) Collection (water gathers)."
#
# New Prompt:
# Prompt_Type: Command
# Prompt_Length: 36
# Prompt: 'List the primary colors of light and how they create other colours.'
# Response: "The primary colors of light are red, green, and blue. Mixing them in different combinations creates all other visible colors."
#
# New Prompt:
# Prompt_Type: Command
# Prompt_Length: 35
# Prompt: 'Describe the main components of a computer.'
# Response: "The main components of a computer are: CPU, memory, storage, input devices (keyboard, mouse), and output devices (monitor, printer)."

# %% [markdown]
# Question 11
#
# "You're tasked with generating a prompt in the same style as top scoring ones. Use few-shot prompting to help the LLM learn the 'style' of successful prompts, then apply it to a new topic."
#
# What it Tests : Pattern abstraction , Prompt consistency
#
# Candidate Task : Identify top prompts and create a prompt to generate new ones in the same format.

# %%
PROMPT = """ Analyze the prompts and based on the prompts that perform well, generate a new prompt in the same style as the successful examples provided below.
Here are two examples of high-performing prompts from the dataset. You have to go through these prompts and understand the similar pattern they 
are wrriten in and undertand the style. 

Example 1:
Prompt: "Summarize the plot of Romeo and Juliet."
Prompt_Type: Command
Prompt_Length: 39
Response: "Romeo and Juliet is a tragedy by William Shakespeare that tells the story of two young star-crossed lovers whose deaths ultimately reconcile their feuding families."

Example 2:
Prompt: "List the ingredients for making pizza."
Prompt_Type: Command
Prompt_Length: 38
Response: "To make pizza, you'll need dough, tomato sauce, cheese, and your choice of toppings like pepperoni, mushrooms, and bell peppers."

Your task is to generate a new prompt and response that follow this same style. 
The new prompt should have a different theme than these but needs to be of the same style and format.

Follow this structure and give 3 new prompts:
New Prompt:
Prompt_Type: Command
Prompt_Length: [your generated length]
Prompt: '[your generated prompt]'
Response: '[Generate the response]'
"""

full_prompt = f"Given the following dataset from a CSV file, {PROMPT}\n\nDataset:\n{data}"

response = model.generate_content(full_prompt)
print(response.text)
# Out:
# Here are three new prompts generated in a similar style to the high-performing prompts provided in the dataset:
#
# New Prompt 1:
# Prompt_Type: Command
# Prompt_Length: 42
# Prompt: "List the steps involved in changing a car's flat tire."
# Response: "To change a flat tire, you'll need to loosen the lug nuts, jack up the car, remove the flat, put on the spare, and tighten the lug nuts."
#
# New Prompt 2:
# Prompt_Type: Command
# Prompt_Length: 43
# Prompt: "Explain the basic principles of supply and demand in economics."
# Response: "Supply and demand describes how the availability of a product and the desire for it influence its price in a market setting."
#
# New Prompt 3:
# Prompt_Type: Command
# Prompt_Length: 38
# Prompt: "Summarize the plot of William Shakespeare's Hamlet."
# Response: "Hamlet is about the prince seeking revenge for his father's murder and it's the most famous tragedy of Shakespeare's works."

# %% [markdown]
# Question 12
#
# "You don’t know the column headers of this dataset. Use chain-of-thought reasoning to deduce what the likely columns are and what kind of data they contain."
#
# What it Tests : Chain-of-thought reasoning from values , Schema inference
#
# Candidate Task : Prompt the model to deduce schema from a few row values only.

# %%
PROMPT = """Assume you did not have the column headers in it. and read only the 1st 10 rows of the dataset.
From these rows and values you can see that:
The 1st value in each row looks like a question. They are all questions or statements given.
The second values are one of these: "Question," "Command," and "Open-ended".
The 3rd values are positive numerical values ranging from 20 to even 39. 
4th values are phrases like "In 5 years..." and "Romeo and Juliet is..." which look like answeres.

Based on these analysis, infer the data given and provide a description of each for each of the 1st, 2nd, 3rd and 4th value.
Give a general description of what these column values are.
"""

full_prompt = f"Given the following dataset from a CSV file, {PROMPT}\n\nDataset:\n{data}"

response = model.generate_content(full_prompt)
print(response.text)
# Out:
# Here's an analysis of the dataset, along with descriptions for each column:
#
# **General Description of the Columns:**
#
# *   **Column 1: Prompt (Question/Statement):** This column contains the core of the interaction – a question, a command, or a statement. These are the inputs or initiations for a response.
# *   **Column 2: Prompt_Type:** This column categorizes the type of prompt provided in Column 1.
# *   **Column 3: Prompt_Length:** This column contains the length of each question or prompt.
# *   **Column 4: Response:** This column contains the answer or the feedback.
#
# **Analysis of the First 10 Rows:**
#
# | **Column 1: Prompt (Question/Statement)** | **Column 2: Prompt\_Type** | **Column 3: Prompt\_Length** | **Column 4: Response**                                                                    | Description                                                                   |
# | :---------------------------------------- | :------------------------- | :------------------------- | :---------------------------------------------------------------------------------------- | :---------------------------------------------------------------------------- |
# | Where do you see yourself in 5 years?     | Question                   | 37                         | In 5 years, I see myself advancing in my career and possibly settling down with a family. |  A thought-provoking question, likely to be answered with a personal reflection.                                                            |
# | Summarize the plot of Romeo and Juliet.  | Command                    | 39                         | Romeo and Juliet is a tragedy by William Shakespeare that tells the story of two young star-crossed lovers whose deaths ultimately reconcile their feuding families.  |  A command requesting a specific summarization.                                                                           |
# | I'm feeling sad today.                   | Open-ended                 | 22                         | I'm sorry to hear that you're feeling down. It's okay to have off days, and it's important to take time to care for yourself.          | An open-ended statement, allowing for a wide range of responses.                                      |
# | Why do you think education is important?  | Question                   | 40                         | I believe education is important because it empowers individuals and contributes to societal progress.  |  A question that prompts for a reason or explanation.                                     |
# | List the ingredients for making pizza.    | Command                    | 38                         | To make pizza, you'll need dough, tomato sauce, cheese, and your choice of toppings like pepperoni, mushrooms, and bell peppers. |  A command that demands a list or set of details.                                     |
# | I don't understand calculus.             | Open-ended                 | 28                         | Calculus can be challenging, but with the right resources and dedication, you can certainly grasp it.  | An open-ended statement, allowing for a wide range of responses.                                      |
# | Why do you think education is important?  | Question                   | 40                         | I believe education is important because it empowers individuals and contributes to societal progress.  |  A question that prompts for a reason or explanation.                                     |
# | Describe the process of photosynthesis.   | Command                    | 39                         | Photosynthesis is the process by which green plants convert carbon dioxide and water into glucose and oxygen, using sunlight.        |  A command that demands a description.                                         |
# | I don't understand calculus.             | Open-ended                 | 28                         | Calculus can be challenging, but with the right resources and dedication, you can certainly grasp it.  | An open-ended statement, allowing for a wide range of responses.                                      |
# | What are the benefits of exercise?      | Question                   | 34                         | Exercise helps improve physical health, boosts mental well-being, and enhances cognitive function. |  A question that expects a list or explanation of benefits.                                 |
#
# **Inferred Data and Descriptions:**
#
# *   **Column 1: Prompt:**
#     *   **Description:** This is the user's input. It is the stimulus for a response.
#     *   **Examples:** Questions ("Where do you see yourself in 5 years?"), Commands ("Summarize the plot of Romeo and Juliet."), Statements ("I'm feeling sad today.").
#
# *   **Column 2: Prompt\_Type:**
#     *   **Description:** Categorizes the nature of the input in Column 1.
#     *   **Values:**
#         *   "Question": Input is a question.
#         *   "Command": Input is a command or instruction.
#         *   "Open-ended": Input is a statement, or a general inquiry that doesn't fit neatly into a question or command.
#
# *   **Column 3: Prompt\_Length:**
#     *   **Description:** Provides a numerical value indicating the length of the user's input. This gives information about the complexity or length of the prompt.
#     *   **Example Values:** 20, 37, 39, 40, which represent the number of characters in the prompt.
#
# *   **Column 4: Response:**
#     *   **Description:** This column contains the system's response to the prompt.
#     *   **Examples:** Answers to questions ("In 5 years, I see myself..."), Summaries ("Romeo and Juliet is a tragedy..."), Supportive statements ("I'm sorry to hear that you're feeling down.").

# %% [markdown]
#
#
# Question 13
#
# "Design a prompt that not only analyzes failing strategies but teaches the model how to improve based on similar successful examples."
#
# What it Tests : Merged few-shot + CoT , Teaching-through-prompting
#
# Candidate Task : Provide few examples of poor-performing rows, compare with high-performing ones, and generate improvement strategy.

# %%
PROMPT = """Analyse the data and the prompt performance and provide a strategy for improvement.
Here is a hypothetical example of a poor-performing prompt and its response, followed by a high-performing example for comparison.
**Poor-Performing Example:**

Example 1:
Prompt: "Tell me about cars."
Prompt_Type: Open-ended
Prompt_Length: 17
Response: "Cars are a type of vehicle used for transportation."

This response is considered poor because it's too general and lacks detail, is short and generic since other vehicals are aslo used for transportation. 
The response should also include aspects related to the design and looks of a car. 

Example 2:
Prompt: "Explain technology."
Prompt_Type: Open-ended
Prompt_Length: 20
Response: "Technology refers to tools and machines that help people."
Why It's Poor:
Overly simplistic and vague.
Lacks examples or categories.
Doesnt consider the scope of modern technology (e.g., AI, smartphones, etc.)

Example 3:
Prompt: "Write something about food."
Prompt_Type: Open-ended
Prompt_Length: 25
Response: "Food is something we eat to live."
Why It's Poor:
Fails to add value—doesnt mention types, culture, taste, or nutrition.
Extremely basic and redundant information.

**High-Performing Example:**

Example 1:
Prompt: "Why do you think education is important?"
Prompt_Type: Question
Prompt_Length: 40
Response: "I believe education is important because it empowers individuals and contributes to societal progress."
This response is considered high-performing because it's detailed, insightful, and goes beyond a simple definition.
It is a specific question that asks for an opinion or a deeper analysis. It's longer and more detailed, which provides better context.

Example 2:
Prompt: "How has the internet changed communication in the last decade?"
Prompt_Type: Question
Prompt_Length: 52
Response: "The internet has made communication faster, more global, and accessible, transforming both personal interactions and professional collaboration."
Why It's Good:
Focused, time-bound, and analytical.
Encourages specific, multifaceted answers.


Now analyze the difference between these examples of poor and high performing prompts and then propose a strategy for improving any poor-performing prompts.
What should we keep in mind while writing prompts so that the responses and well written.
For example: To improve the "Tell me about cars" prompt, we should make it more specific. Instead of asking for a general summary, we should ask a focused question.
Based on this, provide a new, improved version of the poor-performing prompt and explain the strategy you used to make it better.
"""

full_prompt = f"{PROMPT}"

response = model.generate_content(full_prompt)
print(response.text)
# Out:
# ## Analysis of Poor vs. High-Performing Prompts and Improvement Strategy
#
# **Key Differences Between Poor and High-Performing Prompts:**
#
# The primary difference lies in the **specificity and depth** of the prompt.
#
# *   **Poor Prompts:**
#     *   Are too **broad and general**.
#     *   Often ask for a simple definition or a superficial overview.
#     *   Result in short, generic, and uninformative responses.
#     *   Lack clear direction for the AI, leading to basic answers.
#     *   Use passive language and dont specify the type of response or analysis expected.
#
# *   **High-Performing Prompts:**
#     *   Are **specific and focused**, targeting a particular aspect or angle.
#     *   Often framed as questions or requests for analysis, comparison, or explanation.
#     *   Encourage more detailed and insightful responses.
#     *   Provide context and direction, guiding the AI towards a more complete and informative answer.
#     *   Use active language which pushes the AI to take action.
#
# **General Strategy for Improving Poor-Performing Prompts:**
#
# The core strategy is to **move from broad generalization to focused specificity**. Here's a breakdown:
#
# 1.  **Identify the Core Issue:** Analyze why the original prompt resulted in a poor response. What information was missing? What aspects were not addressed?
# 2.  **Refine the Focus:**  Narrow the scope of the prompt to a specific area, aspect, or question related to the topic.
# 3.  **Incorporate Depth:**  Encourage deeper analysis, explanation, comparison, or reflection. This often involves asking "why," "how," "what are the implications of," or "what are the differences between" questions.
# 4.  **Provide Context:** If necessary, include context or background information to help the AI understand the intent of the prompt.
# 5.  **Use Active Language:** Frame the prompt in a way that encourages the AI to perform an action or give a specific type of response (e.g., "Explain," "Compare," "Analyze," "Discuss").
# 6.  **Set a Goal for the Response:** Decide what you want to gain by using the prompt (e.g., Understanding, Information, Comparisons).
#
# **Applying the Strategy to Improve Poor-Performing Prompts:**
#
# Let's take each poor-performing prompt and improve it:
#
# **Poor-Performing Prompt 1:** "Tell me about cars."
#
# *   **Original Analysis:**  Too generic. The response is a simple definition. It lacks information on design, types, features, or impact.
# *   **Improved Strategy Applied:** Focused specificity, deeper exploration of a specific aspect.
# *   **Improved Prompt:** "Compare and contrast the key differences between electric vehicles (EVs) and gasoline-powered cars, considering factors like performance, environmental impact, and long-term costs."
# *   **Explanation of Improvement:**
#     *   **Specific Focus:**  Directs the AI to compare EVs and gasoline cars.
#     *   **Detailed Aspects:** The prompt requires the AI to consider specific factors like performance, environmental impact, and cost.
#     *   **Analytical Approach:** Encourages a comparative analysis rather than a superficial overview.
#     *   **Goal:** Improved understanding by comparison of the two vehicle types.
#
# **Poor-Performing Prompt 2:** "Explain technology."
#
# *   **Original Analysis:** Overly simplistic. Lacks examples or categories. Doesn't reflect the scope of modern technology.
# *   **Improved Strategy Applied:** Focus on a specific area of technology, encourage analysis.
# *   **Improved Prompt:** "How have advancements in artificial intelligence (AI) impacted the job market in the last five years? Discuss both the positive and negative effects."
# *   **Explanation of Improvement:**
#     *   **Specific Focus:** Deals with AI.
#     *   **Analytical Approach:** Asks about impact on the job market and requires a discussion of both pros and cons.
#     *   **Time Bound:** Encourages the AI to focus its answer on changes in recent years.
#     *   **Goal:** Develop an understanding of recent changes related to jobs.
#
# **Poor-Performing Prompt 3:** "Write something about food."
#
# *   **Original Analysis:**  Fails to add value. Redundant and basic information.
# *   **Improved Strategy Applied:** Target specific aspects of food and create depth.
# *   **Improved Prompt:** "How has globalization influenced the dietary habits and culinary traditions of people in different regions of the world?"
# *   **Explanation of Improvement:**
#     *   **Specific Focus:** Investigates the impact of globalization on food.
#     *   **Analytical Approach:** Requires the AI to discuss cultural influences and the changes to culinary traditions.
#     *   **Goal:** Develops an understanding of the effect of globalization on food.
#
# **Key Takeaways for Prompt Writing:**
#
# *   **Be Specific:** Narrow down your topic.
# *   **Ask Questions:** Encourage analysis and deeper thought.
# *   **Provide Context:** Give the AI a framework for understanding.
# *   **Use Action Verbs:** Guide the AI to provide the type of response you want (e.g., "Analyze," "Compare," "Explain," "Evaluate").
# *   **Consider the Goal:** What do you want to learn or understand from the response? Frame your prompt accordingly.
